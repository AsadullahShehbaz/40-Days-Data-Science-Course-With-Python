# %%
import seaborn as sns
import pandas as pd 
df = pd.read_excel('progressSemester6.xlsx')

# %%
df.groupby(['AI']).head()
# Out:
#                   Date                       CN             AI  \
# 0   2025-02-10 00:00:00   Lecture 2 (Chapter 2)      Lecture 6
# 1   2025-02-11 00:00:00               Lecture 3     Lecture 7
# 2   2025-02-12 00:00:00               Lecture 4      Lecture 8
# 3   2025-03-11 00:00:00  Lect 1,2 Gate Smashers      Lecture 9
# 4   2025-03-13 00:00:00            Lec 3 TCP/IP     Lecture 10
# 5   2025-03-14 00:00:00                  LEC 4      Lecture 11
# 6   2025-03-15 00:00:00                     NaN     Lecture 12
# 8   2025-03-17 00:00:00               Lec 7,8,9     Lecture 13
# 9   2025-03-18 00:00:00              Lec 10,11      Lecture 14
# 10  2025-03-19 00:00:00               Lec 12,13     Lecture 15
# 11  2025-03-20 00:00:00               Lec 14,15     Lecture 16
# 12  2025-03-21 00:00:00               Lec 16,17     Lecture 17
# 13  2025-03-23 00:00:00                     NaN  Lecture 27 ML
# 14  2025-03-24 00:00:00                  Lec 18  Lecture 28 ML
# ...
